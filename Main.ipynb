# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import re
import os
import ast  # For safely converting string representations of lists to actual lists
import jdatetime  # Library for converting Gregorian to Jalali
import openpyxl
import numpy as np



# Function to fetch data for a specific date from the API
def fetch_data(date):
    print(f"Fetching data from API for date: {date}")
    url = f"https://fund.fipiran.ir/api/v1/fund/fundcompare?date={date}"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        print(f"Data fetched successfully for {date}")
        return response.json()
    else:
        print(f"Failed to fetch data for {date}. Status code: {response.status_code}")
        return None
    
    
# Function to fetch fund types
def fetch_fund_types():
    url = "https://fund.fipiran.ir/api/v1/fund/fundtype"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        items_df = pd.json_normalize(data['items'])
        items_df['name'] = items_df['name'].str.replace(r'^در\s*', '', regex=True)
        print("Fund types fetched successfully.")
        return items_df
    else:
        print(f"Failed to fetch fund types. Status code: {response.status_code}")
        return pd.DataFrame()


# Function to fetch full data for given regNos and date range
def fetch_instrument_data(regno, date, session):
    print(f"Fetching full instrument data for regNo: {regno} on {date}")
    url = f"https://fund.fipiran.ir/api/v1/fund/getfund?regno={regno}&date={date}"
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()

        if data and "item" in data:
            item_data = data["item"]
            df = pd.DataFrame([item_data])
            df.drop(columns=['name'], errors='ignore', inplace=True)
            return df
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for regNo: {regno} on {date} - {e}")
    return None


# Function to save JSON data to a DataFrame (now extracting from item column)
def save_to_dataframe(data):
    if data and 'items' in data:
        df = pd.DataFrame(data['items'])  # Flatten the nested 'items' list
        return df
    else:
        return pd.DataFrame()
    

# Function to process and flatten the mutualFundLicenses column into multiple columns
def process_mutual_fund_licenses(file_path):
    # Load the file into a DataFrame
    df = pd.read_excel(file_path, engine='openpyxl')

    # Check if the 'mutualFundLicenses' column exists in the DataFrame
    if 'mutualFundLicenses' in df.columns:
        # Convert the string representations of lists into actual lists
        df['mutualFundLicenses'] = df['mutualFundLicenses'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])

        # Extract the dictionary from the list in the 'mutualFundLicenses' column
        df['mutualFundLicenses'] = df['mutualFundLicenses'].apply(
            lambda x: x[0] if isinstance(x, list) and len(x) > 0 else {}  # Extract first dictionary in the list
        )

        # Normalize the dictionary into separate columns
        licenses_df = pd.json_normalize(df['mutualFundLicenses'])

        # Drop the 'regNo' column from licenses_df to avoid the column overlap
        licenses_df = licenses_df.drop(columns=['regNo'], errors='ignore')

        # Merge the normalized data back with 'regNo' and drop the original 'mutualFundLicenses' column
        result_df = df.drop(columns=['mutualFundLicenses']).join(licenses_df)

        # Save the result to a new file or the same file with the sheet name changed to 'Fund_data'
        result_df.to_excel(file_path, index=False, engine='openpyxl')
        print(f"Data successfully processed and saved to {file_path} with sheet name 'Fund_data'.")
        return result_df



# Function to fetch and process data for a date range
def fetch_and_process_data(start_date, end_date, csv_filename):
    fund_types_df = fetch_fund_types()
    all_data = []

    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime("%Y-%m-%d")
        data = fetch_data(date_str)
        if data:
            new_data_df = save_to_dataframe(data)
            if not new_data_df.empty:
                new_data_df['date'] = date_str
                all_data.append(new_data_df)
        current_date += timedelta(days=1)  # Move to next date

    if all_data:
        combined_df = pd.concat(all_data, ignore_index=True)
        if not fund_types_df.empty:
            combined_df = pd.merge(
                combined_df, fund_types_df, on='fundType', how='left'
            )

        # Save to CSV or Excel
        combined_df.to_csv(csv_filename, index=False)
        print(f"Data saved to {csv_filename}.")
        return combined_df
    else:
        print("No data fetched.")
        return pd.DataFrame()

def post_process_data(updated_csv_filename):
    try:
        print(f"Reading post-processing data from {updated_csv_filename}...")
        
        # Read as an Excel file instead of CSV
        df = pd.read_excel(updated_csv_filename, engine='openpyxl')

        # Normalize text to remove non-standard spaces and characters
        df = df.applymap(lambda x: re.sub(r'[\u200c\u00A0ـ]', ' ', str(x)) if isinstance(x, str) else x)

        # Convert column names to strings before renaming
        df.columns = df.columns.astype(str)

        # 1. Rename 'name_x' to 'fund_name'
        df.rename(columns={'name_x': 'fund_name'}, inplace=True)

        # 2. Remove ranking columns
        columns_to_remove = [
            'rankOf12Month', 'rankOf24Month', 'rankOf36Month',
            'rankOf48Month', 'rankOf60Month', 'rankLastUpdate'
        ]
        df.drop(columns=columns_to_remove, errors='ignore', inplace=True)

        # 3. Rename columns ending with 'Efficiency' to 'Return'
        df.rename(columns=lambda x: x.replace('Efficiency', 'Return') if 'Efficiency' in x else x, inplace=True)

        # 4. Rename 'efficiency' column to 'CumulativeReturn'
        df.rename(columns={'efficiency': 'CumulativeReturn'}, inplace=True)

        # 5. Clean 'websiteAddress' column
        if 'websiteAddress' in df.columns:
            df['websiteAddress'] = df['websiteAddress'].str.strip("[]'\"")

        # 6. Rename 'name_y' to 'fundType_name' after the merge step
        df.rename(columns={'name_y': 'fundType_name'}, inplace=True)

        # 7. Clean 'auditor' column
        if 'auditor' in df.columns:
            df['auditor'] = df['auditor'].apply(lambda x: re.sub(r'حسابرس\s*\((.*?)\)', r'\1', str(x)))

        # 8. Clean 'manager' column
        if 'manager' in df.columns:
            def clean_manager(x):
                x = str(x)
                x = re.sub(r'مدیر\s*\((.*?)\)', r'\1', x)
                x = re.sub(r'تامین سرمایه تمدن\s*\(سهامی عام\)', 'تامین سرمایه تمدن', x)
                x = re.sub(r'کارگزاری بانک ملی ایران\s*،\s*مدیر', 'کارگزاری بانک ملی ایران', x)
                return x
            df['manager'] = df['manager'].apply(clean_manager)

        # 9. Clean 'custodian' column
        if 'custodian' in df.columns:
            df['custodian'] = df['custodian'].apply(lambda x: re.sub(r'متولی\s*\((.*?)\)', r'\1', str(x)))

        # 10. Standardize specific names ("نو ویرا" -> "نوویرا")
        df = df.applymap(lambda x: re.sub(r'نو\s+ویرا', 'نوویرا', str(x)) if isinstance(x, str) else x)

        # 11. Convert scientific notation to normal numbers in fundSize, netAsset, and insCode columns
        for col in ['fundSize', 'netAsset', 'insCode']:
            if col in df.columns:
                df[col] = df[col].apply(lambda x: f'{x:.0f}' if isinstance(x, (int, float)) else x)

        # 12. Standardize "سبد گردان" to "سبدگردان"
        df = df.applymap(lambda x: re.sub(r'سبد\s+گردان', 'سبدگردان', str(x)) if isinstance(x, str) else x)

        # 13. Normalize and standardize "سرمایه گذاری" to "سرمایه‌گذاری"
        df = df.applymap(lambda x: re.sub(r'سرمایه\s+گذاری', 'سرمایه‌گذاری', str(x)) if isinstance(x, str) else x)

        # 14. Fix missing spaces after "مشاور"
        df = df.applymap(lambda x: re.sub(r'(مشاور)(سرمایه‌گذاری)', r'\1 \2', str(x)) if isinstance(x, str) else x)

        # # 15. **Divide specific columns by 100**
        # percentage_columns = [
        #     'dailyReturn', 'weeklyReturn', 'monthlyReturn', 
        #     'quarterlyReturn', 'sixMonthReturn', 'annualReturn', 'CumulativeReturn', 'fiveBest',
        #     'stock', 'bond', 'other', 'cash', 'deposit', 'insInvPercent', 'legalPercent', 'naturalPercent',
        #     'retInvPercent',  
        # ]
        
        # for col in percentage_columns:
        #     if col in df.columns:
        #         df[col] = df[col] / 100

        # 16. **Format date columns properly**
        date_columns = ['initiationDate', 'date', 'lastModificationTime', 'registerDate', 'seoRegisterDate', 'startDate']

        # 17. **Convert "date" column to Jalali (Shamsi) and add "shamsi_date" column**
        if 'date' in df.columns:
            def gregorian_to_jalali(g_date):
                if pd.notna(g_date):  # Ensure it's a valid date
                    try:
                        g_date = pd.to_datetime(g_date)  # Ensure it's a datetime object
                        j_date = jdatetime.datetime.fromgregorian(year=g_date.year, month=g_date.month, day=g_date.day)
                        return j_date.strftime('%Y - %m - %d')  # Format as YYYY - MM - DD
                    except:
                        return None
                return None

            df['shamsi_date'] = df['date'].apply(gregorian_to_jalali)

        # 18. **Remove (سهامی خاص) and (سهامی عام) from names**
        df = df.applymap(lambda x: re.sub(r'\s*\(سهامی خاص\)', '', str(x)) if isinstance(x, str) else x)
        df = df.applymap(lambda x: re.sub(r'\s*\(سهامی عام \)\s*', '', str(x)) if isinstance(x, str) else x)

        # 19. **Remove سهامی عام when it appears separately at the end**
        df = df.applymap(lambda x: re.sub(r'\s*سهامی عام$', '', str(x)) if isinstance(x, str) else x)

        # 20. **Replace "نامشخصنامشخص" with an empty string**
        df = df.applymap(lambda x: '' if isinstance(x, str) and 'نامشخصنامشخص' in x else x)

        # Save updated data
        df.to_excel(updated_csv_filename, index=False, sheet_name='Fund_data', engine='openpyxl')
        print(f"Post-processing completed. Updated data saved to {updated_csv_filename}.")

    except FileNotFoundError:
        print(f"Error: {updated_csv_filename} does not exist. Please check the previous steps.")



#import numpy as np  # Add this import

def merge_instrument_data(regnos, dates, output_filename, csv_filename, updated_csv_filename):
    print(f"Starting to fetch full instrument data for {len(regnos)} regNos and {len(dates)} dates...")
    all_results = []
    
    with requests.Session() as session:
        for regno in regnos:
            for date in dates:
                result = fetch_instrument_data(regno, date, session)
                if result is not None:
                    all_results.append(result)

    if all_results:
        df_instruments = pd.concat(all_results, ignore_index=True)
        df_instruments.to_excel(output_filename, sheet_name='instruments', index=False)
        print(f"Instrument data saved to {output_filename}.")

        # Read fund data
        df_fund = pd.read_csv(csv_filename)

        # Read instrument data
        df_instruments = pd.read_excel(output_filename, sheet_name='instruments')

        # Convert 'regNo' safely in fund data
        df_fund['regNo'] = pd.to_numeric(df_fund['regNo'], errors='coerce').fillna(0).astype('int64')

        # Convert 'regNo' safely in instrument data
        df_instruments['regNo'] = pd.to_numeric(df_instruments['regNo'], errors='coerce').fillna(0).astype('int64')

        # Convert date columns to datetime
        df_fund['date'] = pd.to_datetime(df_fund['date']).dt.strftime('%Y-%m-%d')
        df_instruments['date'] = pd.to_datetime(df_instruments['date']).dt.strftime('%Y-%m-%d')

        # Drop columns with all NaN values in the instrument data
        df_instruments = df_instruments.dropna(axis=1, how="all")

        # Merge datasets
        df_final = df_fund.merge(df_instruments, on=['regNo', 'date'], how='left', suffixes=("_fund", "_instrument"))

        # Keep:
        # - Columns that end with '_instrument'.
        # - Columns that do NOT end with '_fund' or '_instrument' (such as 'regNo', 'date', etc.).
        df_final = df_final.loc[:, 
            df_final.columns.str.endswith("_fund") | ~df_final.columns.str.endswith(("instrument", "_fund"))
        ]


        # Remove '_instrument' suffix from column names
        df_final.columns = df_final.columns.str.replace('_instrument', '', regex=False)

        # Save merged data
        df_final.to_excel(updated_csv_filename, index=False)
        print(f"Final data saved to {updated_csv_filename}.")
    else:
        print("No instrument data fetched.")


# Index Data ------------------------------------------------------------------------------------

def fetch_and_process_index_data(api_url, output_file):
    """
    Fetch index data from January 1, 2023, to today, filter correctly, 
    calculate daily returns, and save to an Excel file with sheet name 'Index'.
    """
    headers = {"User-Agent": "Mozilla/5.0"}
    start_date = datetime(2025, 2, 17)  # Start date
    end_date = datetime.today()  # End date: Today

    all_index_data = []

    print("📢 Fetching index data. This may take some time...")

    # Fetch all available data
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        json_data = response.json()

        if 'indexB2' in json_data and json_data['indexB2']:
            df = pd.DataFrame(json_data['indexB2'])

            if 'xNivInuClMresIbs' in df.columns:
                df.rename(columns={'dEven': 'Date', 'xNivInuClMresIbs': 'IndexClosingPrice'}, inplace=True)
                df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d')

                # 🛑 Drop all rows before the start date
                df = df[df['Date'] >= start_date]

                # ✅ Keep only the last valid closing price per date
                df = df.sort_values(by=['Date']).groupby('Date').last().reset_index()

                # ✅ Calculate daily return
                df['IndexReturn'] = df['IndexClosingPrice'].pct_change()

                # 🛑 Drop the first row (NaN return)
                df.dropna(subset=['IndexReturn'], inplace=True)

                # ✅ Keep only the required columns
                df = df[['Date', 'IndexReturn']]

                # Append to the main list
                all_index_data.append(df)
        else:
            print("⚠️ Warning: 'indexB2' key missing or empty in API response.")
    else:
        print(f"❌ Failed to fetch index data. Status code: {response.status_code}")
        return

    if all_index_data:
        df_index_combined = pd.concat(all_index_data, ignore_index=True)

        # ✅ Save to an Excel file
        df_index_combined.to_excel(output_file, sheet_name='Index', index=False)
        print(f"✅ Index data with returns saved to {output_file}.")
    else:
        print("❌ No index data fetched.")

# Merge ---------------------------------------------------------------------------------------- 
def merge_fund_and_index_data(fund_file, index_file, output_file):
    """
    Merges the fund data with the index data on date, 
    keeping only rows where IndexReturn is not NaN.
    """
    print(f"🔄 Merging {fund_file} and {index_file}...")
    
    # Load fund data
    df_fund = pd.read_excel(fund_file, engine="openpyxl")
    
    # Load index data
    df_index = pd.read_excel(index_file, sheet_name="Index", engine="openpyxl")

    # Convert dates to datetime format
    df_fund["date"] = pd.to_datetime(df_fund["date"])
    df_index["Date"] = pd.to_datetime(df_index["Date"])

    # Merge fund and index data on the date column (inner join to keep only matching dates)
    merged_df = pd.merge(df_fund, df_index, left_on="date", right_on="Date", how="inner")

    # Drop the extra Date column from index dataset
    merged_df.drop(columns=["Date"], inplace=True)

    # 🛑 **Ensure percentage values are divided by 100 in the final output**
    percentage_columns = [
        'dailyReturn', 'weeklyReturn', 'monthlyReturn', 
        'quarterlyReturn', 'sixMonthReturn', 'annualReturn', 'CumulativeReturn', 'fiveBest',
        'stock', 'bond', 'other', 'cash', 'deposit', 'insInvPercent', 'legalPercent', 'naturalPercent',
        'retInvPercent',  
    ]

    for col in percentage_columns:
        if col in merged_df.columns:
            merged_df[col] = merged_df[col] / 100

    # Save merged data
    merged_df.to_excel(output_file, index=False, engine="openpyxl")
    print(f"✅ Merged data saved to {output_file}")

# Main execution flow----------------------------------------------------------------------------
if __name__ == "__main__":
    # Define the start and end date range
    start_date = datetime(2025, 2, 17)
    end_date = datetime.today()
    csv_filename = "fund_data.csv"
    updated_csv_filename = "updated_fund_data.xlsx"
    output_filename = "instrument_data.xlsx"

    # Index data
    index_api_url = "https://cdn.tsetmc.com/api/Index/GetIndexB2History/32097828799138957"
    output_index_file = "index_data.xlsx"  

    final_output_file = "final_fund_index_data.xlsx"

    # Step 1: Fetch and save fund data for the date range
    print(f"Fetching and processing fund data from {start_date} to {end_date}...")
    raw_data = fetch_and_process_data(start_date, end_date, csv_filename)

    # Step 2: Check if the CSV file is created before continuing
    if os.path.exists(csv_filename):
        print(f"Reading regNos and dates from {csv_filename}...")
        df_raw = pd.read_csv(csv_filename)
        regnos = df_raw['regNo'].drop_duplicates().tolist() if 'regNo' in df_raw.columns else []
        dates = df_raw['date'].drop_duplicates().tolist() if 'date' in df_raw.columns else []

        # Step 3: Fetch and merge instrument data
        if regnos and dates:
            print(f"Fetching instrument data for {len(regnos)} regNos and {len(dates)} dates...")
            merge_instrument_data(regnos, dates, output_filename, csv_filename, updated_csv_filename)

        # Step 4: Process mutual fund licenses
        if os.path.exists(updated_csv_filename):
            print("Applying mutualFundLicenses processing function...")
            process_mutual_fund_licenses(updated_csv_filename)

            # Step 5: Post-processing
            print("Post-processing fund data...")
            post_process_data(updated_csv_filename)

            # Ensure the post-processed file exists before merging
            if os.path.exists(updated_csv_filename):

                # Step 6 - Index Data
                fetch_and_process_index_data(index_api_url, output_index_file)

                # Step 7: Merge Fund and Index Data
                merge_fund_and_index_data(updated_csv_filename, output_index_file, final_output_file)
            else:
                print(f"Error: {updated_csv_filename} does not exist after post-processing. Check the previous steps.")

        else:
            print(f"Error: {updated_csv_filename} does not exist after processing. Please check the previous steps.")

    else:
        print(f"Error: {csv_filename} does not exist. Please check the previous steps.")
# Out:
# Fetching and processing fund data from 2025-02-17 00:00:00 to 2025-02-19 17:31:09.902650...
# Fund types fetched successfully.
# Fetching data from API for date: 2025-02-17
# Data fetched successfully for 2025-02-17
# Fetching data from API for date: 2025-02-18
# Data fetched successfully for 2025-02-18
# Fetching data from API for date: 2025-02-19
# Data fetched successfully for 2025-02-19
# Data saved to fund_data.csv.
# Reading regNos and dates from fund_data.csv...
# Fetching instrument data for 468 regNos and 2 dates...
# Starting to fetch full instrument data for 468 regNos and 2 dates...
# Fetching full instrument data for regNo: 10615 on 2025-02-17
# Fetching full instrument data for regNo: 10615 on 2025-02-18
# Fetching full instrument data for regNo: 11967 on 2025-02-17
# Fetching full instrument data for regNo: 11967 on 2025-02-18
# Fetching full instrument data for regNo: 11586 on 2025-02-17
# Fetching full instrument data for regNo: 11586 on 2025-02-18
# Fetching full instrument data for regNo: 11856 on 2025-02-17
# Fetching full instrument data for regNo: 11856 on 2025-02-18
# Fetching full instrument data for regNo: 12012 on 2025-02-17
# Fetching full instrument data for regNo: 12012 on 2025-02-18
# Fetching full instrument data for regNo: 10864 on 2025-02-17
# Fetching full instrument data for regNo: 10864 on 2025-02-18
# Fetching full instrument data for regNo: 12008 on 2025-02-17
# Fetching full instrument data for regNo: 12008 on 2025-02-18
# Fetching full instrument data for regNo: 12043 on 2025-02-17
# Fetching full instrument data for regNo: 12043 on 2025-02-18
# Fetching full instrument data for regNo: 11509 on 2025-02-17
# Fetching full instrument data for regNo: 11509 on 2025-02-18
# Fetching full instrument data for regNo: 12006 on 2025-02-17
# Fetching full instrument data for regNo: 12006 on 2025-02-18
# Fetching full instrument data for regNo: 11556 on 2025-02-17
# Fetching full instrument data for regNo: 11556 on 2025-02-18
# Fetching full instrument data for regNo: 11759 on 2025-02-17
# Fetching full instrument data for regNo: 11759 on 2025-02-18
# Fetching full instrument data for regNo: 11530 on 2025-02-17
# Fetching full instrument data for regNo: 11530 on 2025-02-18
# Fetching full instrument data for regNo: 12182 on 2025-02-17
# Fetching full instrument data for regNo: 12182 on 2025-02-18
# Fetching full instrument data for regNo: 12196 on 2025-02-17
# Fetching full instrument data for regNo: 12196 on 2025-02-18
# Fetching full instrument data for regNo: 11884 on 2025-02-17
# Fetching full instrument data for regNo: 11884 on 2025-02-18
# Fetching full instrument data for regNo: 11711 on 2025-02-17
# Fetching full instrument data for regNo: 11711 on 2025-02-18
# Fetching full instrument data for regNo: 11710 on 2025-02-17
# Fetching full instrument data for regNo: 11710 on 2025-02-18
# Fetching full instrument data for regNo: 11286 on 2025-02-17
# Fetching full instrument data for regNo: 11286 on 2025-02-18
# Fetching full instrument data for regNo: 11921 on 2025-02-17
# Fetching full instrument data for regNo: 11921 on 2025-02-18
# Fetching full instrument data for regNo: 12056 on 2025-02-17
# Fetching full instrument data for regNo: 12056 on 2025-02-18
# Fetching full instrument data for regNo: 12057 on 2025-02-17
# Fetching full instrument data for regNo: 12057 on 2025-02-18
# Fetching full instrument data for regNo: 11443 on 2025-02-17
# Fetching full instrument data for regNo: 11443 on 2025-02-18
# Fetching full instrument data for regNo: 11947 on 2025-02-17
# Fetching full instrument data for regNo: 11947 on 2025-02-18
# Fetching full instrument data for regNo: 12169 on 2025-02-17
# Fetching full instrument data for regNo: 12169 on 2025-02-18
# Fetching full instrument data for regNo: 12087 on 2025-02-17
# Fetching full instrument data for regNo: 12087 on 2025-02-18
# Fetching full instrument data for regNo: 11799 on 2025-02-17
# Fetching full instrument data for regNo: 11799 on 2025-02-18
# Fetching full instrument data for regNo: 11668 on 2025-02-17
# Fetching full instrument data for regNo: 11668 on 2025-02-18
# Fetching full instrument data for regNo: 11978 on 2025-02-17
# Fetching full instrument data for regNo: 11978 on 2025-02-18
# Fetching full instrument data for regNo: 11915 on 2025-02-17
# Fetching full instrument data for regNo: 11915 on 2025-02-18
# Fetching full instrument data for regNo: 11755 on 2025-02-17
# Fetching full instrument data for regNo: 11755 on 2025-02-18
# Fetching full instrument data for regNo: 11783 on 2025-02-17
# Fetching full instrument data for regNo: 11783 on 2025-02-18
# Fetching full instrument data for regNo: 11633 on 2025-02-17
# Fetching full instrument data for regNo: 11633 on 2025-02-18
# Fetching full instrument data for regNo: 12127 on 2025-02-17
# Fetching full instrument data for regNo: 12127 on 2025-02-18
# Fetching full instrument data for regNo: 11933 on 2025-02-17
# Fetching full instrument data for regNo: 11933 on 2025-02-18
# Fetching full instrument data for regNo: 11626 on 2025-02-17
# Fetching full instrument data for regNo: 11626 on 2025-02-18
# Fetching full instrument data for regNo: 12217 on 2025-02-17
# Fetching full instrument data for regNo: 12217 on 2025-02-18
# Fetching full instrument data for regNo: 12233 on 2025-02-17
# Fetching full instrument data for regNo: 12233 on 2025-02-18
# Fetching full instrument data for regNo: 11726 on 2025-02-17
# Fetching full instrument data for regNo: 11726 on 2025-02-18
# Fetching full instrument data for regNo: 12163 on 2025-02-17
# Fetching full instrument data for regNo: 12163 on 2025-02-18
# Fetching full instrument data for regNo: 12033 on 2025-02-17
# Fetching full instrument data for regNo: 12033 on 2025-02-18
# Fetching full instrument data for regNo: 11706 on 2025-02-17
# Fetching full instrument data for regNo: 11706 on 2025-02-18
# Fetching full instrument data for regNo: 10851 on 2025-02-17
# Fetching full instrument data for regNo: 10851 on 2025-02-18
# Fetching full instrument data for regNo: 11312 on 2025-02-17
# Fetching full instrument data for regNo: 11312 on 2025-02-18
# Fetching full instrument data for regNo: 10872 on 2025-02-17
# Fetching full instrument data for regNo: 10872 on 2025-02-18
# Fetching full instrument data for regNo: 12191 on 2025-02-17
# Fetching full instrument data for regNo: 12191 on 2025-02-18
# Fetching full instrument data for regNo: 10767 on 2025-02-17
# Fetching full instrument data for regNo: 10767 on 2025-02-18
# Fetching full instrument data for regNo: 11215 on 2025-02-17
# Fetching full instrument data for regNo: 11215 on 2025-02-18
# Fetching full instrument data for regNo: 11454 on 2025-02-17
# Fetching full instrument data for regNo: 11454 on 2025-02-18
# Fetching full instrument data for regNo: 11341 on 2025-02-17
# Fetching full instrument data for regNo: 11341 on 2025-02-18
# Fetching full instrument data for regNo: 11889 on 2025-02-17
# Fetching full instrument data for regNo: 11889 on 2025-02-18
# Fetching full instrument data for regNo: 12162 on 2025-02-17
# Fetching full instrument data for regNo: 12162 on 2025-02-18
# Fetching full instrument data for regNo: 11679 on 2025-02-17
# Fetching full instrument data for regNo: 11679 on 2025-02-18
# Fetching full instrument data for regNo: 11364 on 2025-02-17
# Fetching full instrument data for regNo: 11364 on 2025-02-18
# Fetching full instrument data for regNo: 11297 on 2025-02-17
# Fetching full instrument data for regNo: 11297 on 2025-02-18
# Fetching full instrument data for regNo: 11853 on 2025-02-17
# Fetching full instrument data for regNo: 11853 on 2025-02-18
# Fetching full instrument data for regNo: 11132 on 2025-02-17
# Fetching full instrument data for regNo: 11132 on 2025-02-18
# Fetching full instrument data for regNo: 11220 on 2025-02-17
# Fetching full instrument data for regNo: 11220 on 2025-02-18
# Fetching full instrument data for regNo: 10600 on 2025-02-17
# Fetching full instrument data for regNo: 10600 on 2025-02-18
# Fetching full instrument data for regNo: 10743 on 2025-02-17
# Fetching full instrument data for regNo: 10743 on 2025-02-18
# Fetching full instrument data for regNo: 11907 on 2025-02-17
# Fetching full instrument data for regNo: 11907 on 2025-02-18
# Fetching full instrument data for regNo: 10764 on 2025-02-17
# Fetching full instrument data for regNo: 10764 on 2025-02-18
# Fetching full instrument data for regNo: 11786 on 2025-02-17
# Fetching full instrument data for regNo: 11786 on 2025-02-18
# Fetching full instrument data for regNo: 11649 on 2025-02-17
# Fetching full instrument data for regNo: 11649 on 2025-02-18
# Fetching full instrument data for regNo: 11842 on 2025-02-17
# Fetching full instrument data for regNo: 11842 on 2025-02-18
# Fetching full instrument data for regNo: 12210 on 2025-02-17
# Fetching full instrument data for regNo: 12210 on 2025-02-18
# Fetching full instrument data for regNo: 12135 on 2025-02-17
# Fetching full instrument data for regNo: 12135 on 2025-02-18
# Fetching full instrument data for regNo: 10787 on 2025-02-17
# Fetching full instrument data for regNo: 10787 on 2025-02-18
# Fetching full instrument data for regNo: 11617 on 2025-02-17
# Fetching full instrument data for regNo: 11617 on 2025-02-18
# Fetching full instrument data for regNo: 11309 on 2025-02-17
# Fetching full instrument data for regNo: 11309 on 2025-02-18
# Fetching full instrument data for regNo: 10934 on 2025-02-17
# Fetching full instrument data for regNo: 10934 on 2025-02-18
# Fetching full instrument data for regNo: 11157 on 2025-02-17
# Fetching full instrument data for regNo: 11157 on 2025-02-18
# Fetching full instrument data for regNo: 11912 on 2025-02-17
# Fetching full instrument data for regNo: 11912 on 2025-02-18
# Fetching full instrument data for regNo: 11308 on 2025-02-17
# Fetching full instrument data for regNo: 11308 on 2025-02-18
# Fetching full instrument data for regNo: 11962 on 2025-02-17
# Fetching full instrument data for regNo: 11962 on 2025-02-18
# Fetching full instrument data for regNo: 10616 on 2025-02-17
# Fetching full instrument data for regNo: 10616 on 2025-02-18
# Fetching full instrument data for regNo: 11235 on 2025-02-17
# Fetching full instrument data for regNo: 11235 on 2025-02-18
# Fetching full instrument data for regNo: 11858 on 2025-02-17
# Fetching full instrument data for regNo: 11858 on 2025-02-18
# Fetching full instrument data for regNo: 11954 on 2025-02-17
# Fetching full instrument data for regNo: 11954 on 2025-02-18
# Fetching full instrument data for regNo: 11763 on 2025-02-17
# Fetching full instrument data for regNo: 11763 on 2025-02-18
# Fetching full instrument data for regNo: 11709 on 2025-02-17
# Fetching full instrument data for regNo: 11709 on 2025-02-18
# Fetching full instrument data for regNo: 12189 on 2025-02-17
# Fetching full instrument data for regNo: 12189 on 2025-02-18
# Fetching full instrument data for regNo: 11234 on 2025-02-17
# Fetching full instrument data for regNo: 11234 on 2025-02-18
# Fetching full instrument data for regNo: 12099 on 2025-02-17
# Fetching full instrument data for regNo: 12099 on 2025-02-18
# Fetching full instrument data for regNo: 11459 on 2025-02-17
# Fetching full instrument data for regNo: 11459 on 2025-02-18
# Fetching full instrument data for regNo: 11327 on 2025-02-17
# Fetching full instrument data for regNo: 11327 on 2025-02-18
# Fetching full instrument data for regNo: 11287 on 2025-02-17
# Fetching full instrument data for regNo: 11287 on 2025-02-18
# Fetching full instrument data for regNo: 11055 on 2025-02-17
# Fetching full instrument data for regNo: 11055 on 2025-02-18
# Fetching full instrument data for regNo: 11186 on 2025-02-17
# Fetching full instrument data for regNo: 11186 on 2025-02-18
# Fetching full instrument data for regNo: 11183 on 2025-02-17
# Fetching full instrument data for regNo: 11183 on 2025-02-18
# Fetching full instrument data for regNo: 12021 on 2025-02-17
# Fetching full instrument data for regNo: 12021 on 2025-02-18
# Fetching full instrument data for regNo: 11900 on 2025-02-17
# Fetching full instrument data for regNo: 11900 on 2025-02-18
# Fetching full instrument data for regNo: 11828 on 2025-02-17
# Fetching full instrument data for regNo: 11828 on 2025-02-18
# Fetching full instrument data for regNo: 10801 on 2025-02-17
# Fetching full instrument data for regNo: 10801 on 2025-02-18
# Fetching full instrument data for regNo: 11998 on 2025-02-17
# Fetching full instrument data for regNo: 11998 on 2025-02-18
# Fetching full instrument data for regNo: 10591 on 2025-02-17
# Fetching full instrument data for regNo: 10591 on 2025-02-18
# Fetching full instrument data for regNo: 11305 on 2025-02-17
# Fetching full instrument data for regNo: 11305 on 2025-02-18
# Fetching full instrument data for regNo: 12223 on 2025-02-17
# Fetching full instrument data for regNo: 12223 on 2025-02-18
# Fetching full instrument data for regNo: 11258 on 2025-02-17
# Fetching full instrument data for regNo: 11258 on 2025-02-18
# Fetching full instrument data for regNo: 12146 on 2025-02-17
# Fetching full instrument data for regNo: 12146 on 2025-02-18
# Fetching full instrument data for regNo: 11087 on 2025-02-17
# Fetching full instrument data for regNo: 11087 on 2025-02-18
# Fetching full instrument data for regNo: 11477 on 2025-02-17
# Fetching full instrument data for regNo: 11477 on 2025-02-18
# Fetching full instrument data for regNo: 11149 on 2025-02-17
# Fetching full instrument data for regNo: 11149 on 2025-02-18
# Fetching full instrument data for regNo: 11823 on 2025-02-17
# Fetching full instrument data for regNo: 11823 on 2025-02-18
# Fetching full instrument data for regNo: 12015 on 2025-02-17
# Fetching full instrument data for regNo: 12015 on 2025-02-18
# Fetching full instrument data for regNo: 11959 on 2025-02-17
# Fetching full instrument data for regNo: 11959 on 2025-02-18
# Fetching full instrument data for regNo: 11968 on 2025-02-17
# Fetching full instrument data for regNo: 11968 on 2025-02-18
# Fetching full instrument data for regNo: 11182 on 2025-02-17
# Fetching full instrument data for regNo: 11182 on 2025-02-18
# Fetching full instrument data for regNo: 12031 on 2025-02-17
# Fetching full instrument data for regNo: 12031 on 2025-02-18
# Fetching full instrument data for regNo: 11367 on 2025-02-17
# Fetching full instrument data for regNo: 11367 on 2025-02-18
# Fetching full instrument data for regNo: 12154 on 2025-02-17
# Fetching full instrument data for regNo: 12154 on 2025-02-18
# Fetching full instrument data for regNo: 11397 on 2025-02-17
# Fetching full instrument data for regNo: 11397 on 2025-02-18
# Fetching full instrument data for regNo: 11318 on 2025-02-17
# Fetching full instrument data for regNo: 11318 on 2025-02-18
# Fetching full instrument data for regNo: 11722 on 2025-02-17
# Fetching full instrument data for regNo: 11722 on 2025-02-18
# Fetching full instrument data for regNo: 12159 on 2025-02-17
# Fetching full instrument data for regNo: 12159 on 2025-02-18
# Fetching full instrument data for regNo: 11525 on 2025-02-17
# Fetching full instrument data for regNo: 11525 on 2025-02-18
# Fetching full instrument data for regNo: 12035 on 2025-02-17
# Fetching full instrument data for regNo: 12035 on 2025-02-18
# Fetching full instrument data for regNo: 11780 on 2025-02-17
# Fetching full instrument data for regNo: 11780 on 2025-02-18
# Fetching full instrument data for regNo: 11280 on 2025-02-17
# Fetching full instrument data for regNo: 11280 on 2025-02-18
# Fetching full instrument data for regNo: 10830 on 2025-02-17
# Fetching full instrument data for regNo: 10830 on 2025-02-18
# Fetching full instrument data for regNo: 11196 on 2025-02-17
# Fetching full instrument data for regNo: 11196 on 2025-02-18
# Fetching full instrument data for regNo: 11285 on 2025-02-17
# Fetching full instrument data for regNo: 11285 on 2025-02-18
# Fetching full instrument data for regNo: 11461 on 2025-02-17
# Fetching full instrument data for regNo: 11461 on 2025-02-18
# Fetching full instrument data for regNo: 11687 on 2025-02-17
# Fetching full instrument data for regNo: 11687 on 2025-02-18
# Fetching full instrument data for regNo: 11188 on 2025-02-17
# Fetching full instrument data for regNo: 11188 on 2025-02-18
# Fetching full instrument data for regNo: 12160 on 2025-02-17
# Fetching full instrument data for regNo: 12160 on 2025-02-18
# Fetching full instrument data for regNo: 11692 on 2025-02-17
# Fetching full instrument data for regNo: 11692 on 2025-02-18
# Fetching full instrument data for regNo: 12002 on 2025-02-17
# Fetching full instrument data for regNo: 12002 on 2025-02-18
# Fetching full instrument data for regNo: 12208 on 2025-02-17
# Fetching full instrument data for regNo: 12208 on 2025-02-18
# Fetching full instrument data for regNo: 11518 on 2025-02-17
# Fetching full instrument data for regNo: 11518 on 2025-02-18
# Fetching full instrument data for regNo: 12128 on 2025-02-17
# Fetching full instrument data for regNo: 12128 on 2025-02-18
# Fetching full instrument data for regNo: 11838 on 2025-02-17
# Fetching full instrument data for regNo: 11838 on 2025-02-18
# Fetching full instrument data for regNo: 12048 on 2025-02-17
# Fetching full instrument data for regNo: 12048 on 2025-02-18
# Fetching full instrument data for regNo: 11776 on 2025-02-17
# Fetching full instrument data for regNo: 11776 on 2025-02-18
# Fetching full instrument data for regNo: 11931 on 2025-02-17
# Fetching full instrument data for regNo: 11931 on 2025-02-18
# Fetching full instrument data for regNo: 11409 on 2025-02-17
# Fetching full instrument data for regNo: 11409 on 2025-02-18
# Fetching full instrument data for regNo: 11874 on 2025-02-17
# Fetching full instrument data for regNo: 11874 on 2025-02-18
# Fetching full instrument data for regNo: 11993 on 2025-02-17
# Fetching full instrument data for regNo: 11993 on 2025-02-18
# Fetching full instrument data for regNo: 11315 on 2025-02-17
# Fetching full instrument data for regNo: 11315 on 2025-02-18
# Fetching full instrument data for regNo: 12155 on 2025-02-17
# Fetching full instrument data for regNo: 12155 on 2025-02-18
# Fetching full instrument data for regNo: 11660 on 2025-02-17
# Fetching full instrument data for regNo: 11660 on 2025-02-18
# Fetching full instrument data for regNo: 10630 on 2025-02-17
# Fetching full instrument data for regNo: 10630 on 2025-02-18
# Fetching full instrument data for regNo: 11673 on 2025-02-17
# Fetching full instrument data for regNo: 11673 on 2025-02-18
# Fetching full instrument data for regNo: 11990 on 2025-02-17
# Fetching full instrument data for regNo: 11990 on 2025-02-18
# Fetching full instrument data for regNo: 11698 on 2025-02-17
# Fetching full instrument data for regNo: 11698 on 2025-02-18
# Fetching full instrument data for regNo: 12152 on 2025-02-17
# Fetching full instrument data for regNo: 12152 on 2025-02-18
# Fetching full instrument data for regNo: 11883 on 2025-02-17
# Fetching full instrument data for regNo: 11883 on 2025-02-18
# Fetching full instrument data for regNo: 10923 on 2025-02-17
# Fetching full instrument data for regNo: 10923 on 2025-02-18
# Fetching full instrument data for regNo: 12172 on 2025-02-17
# Fetching full instrument data for regNo: 12172 on 2025-02-18
# Fetching full instrument data for regNo: 12209 on 2025-02-17
# Fetching full instrument data for regNo: 12209 on 2025-02-18
# Fetching full instrument data for regNo: 12039 on 2025-02-17
# Fetching full instrument data for regNo: 12039 on 2025-02-18
# Fetching full instrument data for regNo: 11323 on 2025-02-17
# Fetching full instrument data for regNo: 11323 on 2025-02-18
# Fetching full instrument data for regNo: 11667 on 2025-02-17
# Fetching full instrument data for regNo: 11667 on 2025-02-18
# Fetching full instrument data for regNo: 11391 on 2025-02-17
# Fetching full instrument data for regNo: 11391 on 2025-02-18
# Fetching full instrument data for regNo: 10869 on 2025-02-17
# Fetching full instrument data for regNo: 10869 on 2025-02-18
# Fetching full instrument data for regNo: 12050 on 2025-02-17
# Fetching full instrument data for regNo: 12050 on 2025-02-18
# Fetching full instrument data for regNo: 10753 on 2025-02-17
# Fetching full instrument data for regNo: 10753 on 2025-02-18
# Fetching full instrument data for regNo: 12181 on 2025-02-17
# Fetching full instrument data for regNo: 12181 on 2025-02-18
# Fetching full instrument data for regNo: 11148 on 2025-02-17
# Fetching full instrument data for regNo: 11148 on 2025-02-18
# Fetching full instrument data for regNo: 11916 on 2025-02-17
# Fetching full instrument data for regNo: 11916 on 2025-02-18
# Fetching full instrument data for regNo: 10771 on 2025-02-17
# Fetching full instrument data for regNo: 10771 on 2025-02-18
# Fetching full instrument data for regNo: 11841 on 2025-02-17
# Fetching full instrument data for regNo: 11841 on 2025-02-18
# Fetching full instrument data for regNo: 10835 on 2025-02-17
# Fetching full instrument data for regNo: 10835 on 2025-02-18
# Fetching full instrument data for regNo: 11407 on 2025-02-17
# Fetching full instrument data for regNo: 11407 on 2025-02-18
# Fetching full instrument data for regNo: 11753 on 2025-02-17
# Fetching full instrument data for regNo: 11753 on 2025-02-18
# Fetching full instrument data for regNo: 12161 on 2025-02-17
# Fetching full instrument data for regNo: 12161 on 2025-02-18
# Fetching full instrument data for regNo: 12055 on 2025-02-17
# Fetching full instrument data for regNo: 12055 on 2025-02-18
# Fetching full instrument data for regNo: 11955 on 2025-02-17
# Fetching full instrument data for regNo: 11955 on 2025-02-18
# Fetching full instrument data for regNo: 11725 on 2025-02-17
# Fetching full instrument data for regNo: 11725 on 2025-02-18
# Fetching full instrument data for regNo: 11588 on 2025-02-17
# Fetching full instrument data for regNo: 11588 on 2025-02-18
# Fetching full instrument data for regNo: 10596 on 2025-02-17
# Fetching full instrument data for regNo: 10596 on 2025-02-18
# Fetching full instrument data for regNo: 11277 on 2025-02-17
# Fetching full instrument data for regNo: 11277 on 2025-02-18
# Fetching full instrument data for regNo: 11338 on 2025-02-17
# Fetching full instrument data for regNo: 11338 on 2025-02-18
# Fetching full instrument data for regNo: 11712 on 2025-02-17
# Fetching full instrument data for regNo: 11712 on 2025-02-18
# Fetching full instrument data for regNo: 12053 on 2025-02-17
# Fetching full instrument data for regNo: 12053 on 2025-02-18
# Fetching full instrument data for regNo: 12193 on 2025-02-17
# Fetching full instrument data for regNo: 12193 on 2025-02-18
# Fetching full instrument data for regNo: 12017 on 2025-02-17
# Fetching full instrument data for regNo: 12017 on 2025-02-18
# Fetching full instrument data for regNo: 11421 on 2025-02-17
# Fetching full instrument data for regNo: 11421 on 2025-02-18
# Fetching full instrument data for regNo: 11756 on 2025-02-17
# Fetching full instrument data for regNo: 11756 on 2025-02-18
# Fetching full instrument data for regNo: 11470 on 2025-02-17
# Fetching full instrument data for regNo: 11470 on 2025-02-18
# Fetching full instrument data for regNo: 11939 on 2025-02-17
# Fetching full instrument data for regNo: 11939 on 2025-02-18
# Fetching full instrument data for regNo: 11918 on 2025-02-17
# Fetching full instrument data for regNo: 11918 on 2025-02-18
# Fetching full instrument data for regNo: 11500 on 2025-02-17
# Fetching full instrument data for regNo: 11500 on 2025-02-18
# Fetching full instrument data for regNo: 10762 on 2025-02-17
# Fetching full instrument data for regNo: 10762 on 2025-02-18
# Fetching full instrument data for regNo: 11774 on 2025-02-17
# Fetching full instrument data for regNo: 11774 on 2025-02-18
# Fetching full instrument data for regNo: 12051 on 2025-02-17
# Fetching full instrument data for regNo: 12051 on 2025-02-18
# Fetching full instrument data for regNo: 11304 on 2025-02-17
# Fetching full instrument data for regNo: 11304 on 2025-02-18
# Fetching full instrument data for regNo: 11976 on 2025-02-17
# Fetching full instrument data for regNo: 11976 on 2025-02-18
# Fetching full instrument data for regNo: 11378 on 2025-02-17
# Fetching full instrument data for regNo: 11378 on 2025-02-18
# Fetching full instrument data for regNo: 11172 on 2025-02-17
# Fetching full instrument data for regNo: 11172 on 2025-02-18
# Fetching full instrument data for regNo: 10895 on 2025-02-17
# Fetching full instrument data for regNo: 10895 on 2025-02-18
# Fetching full instrument data for regNo: 12199 on 2025-02-17
# Fetching full instrument data for regNo: 12199 on 2025-02-18
# Fetching full instrument data for regNo: 11569 on 2025-02-17
# Fetching full instrument data for regNo: 11569 on 2025-02-18
# Fetching full instrument data for regNo: 11380 on 2025-02-17
# Fetching full instrument data for regNo: 11380 on 2025-02-18
# Fetching full instrument data for regNo: 11562 on 2025-02-17
# Fetching full instrument data for regNo: 11562 on 2025-02-18
# Fetching full instrument data for regNo: 11736 on 2025-02-17
# Fetching full instrument data for regNo: 11736 on 2025-02-18
# Fetching full instrument data for regNo: 11793 on 2025-02-17
# Fetching full instrument data for regNo: 11793 on 2025-02-18
# Fetching full instrument data for regNo: 11195 on 2025-02-17
# Fetching full instrument data for regNo: 11195 on 2025-02-18
# Fetching full instrument data for regNo: 12171 on 2025-02-17
# Fetching full instrument data for regNo: 12171 on 2025-02-18
# Fetching full instrument data for regNo: 10720 on 2025-02-17
# Fetching full instrument data for regNo: 10720 on 2025-02-18
# Fetching full instrument data for regNo: 11995 on 2025-02-17
# Fetching full instrument data for regNo: 11995 on 2025-02-18
# Fetching full instrument data for regNo: 11521 on 2025-02-17
# Fetching full instrument data for regNo: 11521 on 2025-02-18
# Fetching full instrument data for regNo: 10781 on 2025-02-17
# Fetching full instrument data for regNo: 10781 on 2025-02-18
# Fetching full instrument data for regNo: 11365 on 2025-02-17
# Fetching full instrument data for regNo: 11365 on 2025-02-18
# Fetching full instrument data for regNo: 11416 on 2025-02-17
# Fetching full instrument data for regNo: 11416 on 2025-02-18
# Fetching full instrument data for regNo: 11664 on 2025-02-17
# Fetching full instrument data for regNo: 11664 on 2025-02-18
# Fetching full instrument data for regNo: 11161 on 2025-02-17
# Fetching full instrument data for regNo: 11161 on 2025-02-18
# Fetching full instrument data for regNo: 11442 on 2025-02-17
# Fetching full instrument data for regNo: 11442 on 2025-02-18
# Fetching full instrument data for regNo: 11996 on 2025-02-17
# Fetching full instrument data for regNo: 11996 on 2025-02-18
# Fetching full instrument data for regNo: 11168 on 2025-02-17
# Fetching full instrument data for regNo: 11168 on 2025-02-18
# Fetching full instrument data for regNo: 12117 on 2025-02-17
# Fetching full instrument data for regNo: 12117 on 2025-02-18
# Fetching full instrument data for regNo: 10766 on 2025-02-17
# Fetching full instrument data for regNo: 10766 on 2025-02-18
# Fetching full instrument data for regNo: 11420 on 2025-02-17
# Fetching full instrument data for regNo: 11420 on 2025-02-18
# Fetching full instrument data for regNo: 11513 on 2025-02-17
# Fetching full instrument data for regNo: 11513 on 2025-02-18
# Fetching full instrument data for regNo: 11383 on 2025-02-17
# Fetching full instrument data for regNo: 11383 on 2025-02-18
# Fetching full instrument data for regNo: 11095 on 2025-02-17
# Fetching full instrument data for regNo: 11095 on 2025-02-18
# Fetching full instrument data for regNo: 12180 on 2025-02-17
# Fetching full instrument data for regNo: 12180 on 2025-02-18
# Fetching full instrument data for regNo: 10920 on 2025-02-17
# Fetching full instrument data for regNo: 10920 on 2025-02-18
# Fetching full instrument data for regNo: 11268 on 2025-02-17
# Fetching full instrument data for regNo: 11268 on 2025-02-18
# Fetching full instrument data for regNo: 11926 on 2025-02-17
# Fetching full instrument data for regNo: 11926 on 2025-02-18
# Fetching full instrument data for regNo: 12045 on 2025-02-17
# Fetching full instrument data for regNo: 12045 on 2025-02-18
# Fetching full instrument data for regNo: 12024 on 2025-02-17
# Fetching full instrument data for regNo: 12024 on 2025-02-18
# Fetching full instrument data for regNo: 11008 on 2025-02-17
# Fetching full instrument data for regNo: 11008 on 2025-02-18
# Fetching full instrument data for regNo: 11914 on 2025-02-17
# Fetching full instrument data for regNo: 11914 on 2025-02-18
# Fetching full instrument data for regNo: 10784 on 2025-02-17
# Fetching full instrument data for regNo: 10784 on 2025-02-18
# Fetching full instrument data for regNo: 11239 on 2025-02-17
# Fetching full instrument data for regNo: 11239 on 2025-02-18
# Fetching full instrument data for regNo: 11888 on 2025-02-17
# Fetching full instrument data for regNo: 11888 on 2025-02-18
# Fetching full instrument data for regNo: 11379 on 2025-02-17
# Fetching full instrument data for regNo: 11379 on 2025-02-18
# Fetching full instrument data for regNo: 10765 on 2025-02-17
# Fetching full instrument data for regNo: 10765 on 2025-02-18
# Fetching full instrument data for regNo: 11767 on 2025-02-17
# Fetching full instrument data for regNo: 11767 on 2025-02-18
# Fetching full instrument data for regNo: 11419 on 2025-02-17
# Fetching full instrument data for regNo: 11419 on 2025-02-18
# Fetching full instrument data for regNo: 11449 on 2025-02-17
# Fetching full instrument data for regNo: 11449 on 2025-02-18
# Fetching full instrument data for regNo: 12091 on 2025-02-17
# Fetching full instrument data for regNo: 12091 on 2025-02-18
# Fetching full instrument data for regNo: 10883 on 2025-02-17
# Fetching full instrument data for regNo: 10883 on 2025-02-18
# Fetching full instrument data for regNo: 10885 on 2025-02-17
# Fetching full instrument data for regNo: 10885 on 2025-02-18
# Fetching full instrument data for regNo: 11701 on 2025-02-17
# Fetching full instrument data for regNo: 11701 on 2025-02-18
# Fetching full instrument data for regNo: 11741 on 2025-02-17
# Fetching full instrument data for regNo: 11741 on 2025-02-18
# Fetching full instrument data for regNo: 11049 on 2025-02-17
# Fetching full instrument data for regNo: 11049 on 2025-02-18
# Fetching full instrument data for regNo: 11381 on 2025-02-17
# Fetching full instrument data for regNo: 11381 on 2025-02-18
# Fetching full instrument data for regNo: 11859 on 2025-02-17
# Fetching full instrument data for regNo: 11859 on 2025-02-18
# Fetching full instrument data for regNo: 10778 on 2025-02-17
# Fetching full instrument data for regNo: 10778 on 2025-02-18
# Fetching full instrument data for regNo: 11281 on 2025-02-17
# Fetching full instrument data for regNo: 11281 on 2025-02-18
# Fetching full instrument data for regNo: 12070 on 2025-02-17
# Fetching full instrument data for regNo: 12070 on 2025-02-18
# Fetching full instrument data for regNo: 11014 on 2025-02-17
# Fetching full instrument data for regNo: 11014 on 2025-02-18
# Fetching full instrument data for regNo: 10915 on 2025-02-17
# Fetching full instrument data for regNo: 10915 on 2025-02-18
# Fetching full instrument data for regNo: 11989 on 2025-02-17
# Fetching full instrument data for regNo: 11989 on 2025-02-18
# Fetching full instrument data for regNo: 11517 on 2025-02-17
# Fetching full instrument data for regNo: 11517 on 2025-02-18
# Fetching full instrument data for regNo: 11405 on 2025-02-17
# Fetching full instrument data for regNo: 11405 on 2025-02-18
# Fetching full instrument data for regNo: 12042 on 2025-02-17
# Fetching full instrument data for regNo: 12042 on 2025-02-18
# Fetching full instrument data for regNo: 11427 on 2025-02-17
# Fetching full instrument data for regNo: 11427 on 2025-02-18
# Fetching full instrument data for regNo: 11983 on 2025-02-17
# Fetching full instrument data for regNo: 11983 on 2025-02-18
# Fetching full instrument data for regNo: 11273 on 2025-02-17
# Fetching full instrument data for regNo: 11273 on 2025-02-18
# Fetching full instrument data for regNo: 12072 on 2025-02-17
# Fetching full instrument data for regNo: 12072 on 2025-02-18
# Fetching full instrument data for regNo: 11997 on 2025-02-17
# Fetching full instrument data for regNo: 11997 on 2025-02-18
# Fetching full instrument data for regNo: 11920 on 2025-02-17
# Fetching full instrument data for regNo: 11920 on 2025-02-18
# Fetching full instrument data for regNo: 11607 on 2025-02-17
# Fetching full instrument data for regNo: 11607 on 2025-02-18
# Fetching full instrument data for regNo: 10748 on 2025-02-17
# Fetching full instrument data for regNo: 10748 on 2025-02-18
# Fetching full instrument data for regNo: 11919 on 2025-02-17
# Fetching full instrument data for regNo: 11919 on 2025-02-18
# Fetching full instrument data for regNo: 11729 on 2025-02-17
# Fetching full instrument data for regNo: 11729 on 2025-02-18
# Fetching full instrument data for regNo: 11745 on 2025-02-17
# Fetching full instrument data for regNo: 11745 on 2025-02-18
# Fetching full instrument data for regNo: 11158 on 2025-02-17
# Fetching full instrument data for regNo: 11158 on 2025-02-18
# Fetching full instrument data for regNo: 11090 on 2025-02-17
# Fetching full instrument data for regNo: 11090 on 2025-02-18
# Fetching full instrument data for regNo: 11217 on 2025-02-17
# Fetching full instrument data for regNo: 11217 on 2025-02-18
# Fetching full instrument data for regNo: 11476 on 2025-02-17
# Fetching full instrument data for regNo: 11476 on 2025-02-18
# Fetching full instrument data for regNo: 11075 on 2025-02-17
# Fetching full instrument data for regNo: 11075 on 2025-02-18
# Fetching full instrument data for regNo: 11343 on 2025-02-17
# Fetching full instrument data for regNo: 11343 on 2025-02-18
# Fetching full instrument data for regNo: 11917 on 2025-02-17
# Fetching full instrument data for regNo: 11917 on 2025-02-18
# Fetching full instrument data for regNo: 11302 on 2025-02-17
# Fetching full instrument data for regNo: 11302 on 2025-02-18
# Fetching full instrument data for regNo: 11661 on 2025-02-17
# Fetching full instrument data for regNo: 11661 on 2025-02-18
# Fetching full instrument data for regNo: 11098 on 2025-02-17
# Fetching full instrument data for regNo: 11098 on 2025-02-18
# Fetching full instrument data for regNo: 11738 on 2025-02-17
# Fetching full instrument data for regNo: 11738 on 2025-02-18
# Fetching full instrument data for regNo: 11969 on 2025-02-17
# Fetching full instrument data for regNo: 11969 on 2025-02-18
# Fetching full instrument data for regNo: 11808 on 2025-02-17
# Fetching full instrument data for regNo: 11808 on 2025-02-18
# Fetching full instrument data for regNo: 11316 on 2025-02-17
# Fetching full instrument data for regNo: 11316 on 2025-02-18
# Fetching full instrument data for regNo: 12009 on 2025-02-17
# Fetching full instrument data for regNo: 12009 on 2025-02-18
# Fetching full instrument data for regNo: 10911 on 2025-02-17
# Fetching full instrument data for regNo: 10911 on 2025-02-18
# Fetching full instrument data for regNo: 10581 on 2025-02-17
# Fetching full instrument data for regNo: 10581 on 2025-02-18
# Fetching full instrument data for regNo: 10825 on 2025-02-17
# Fetching full instrument data for regNo: 10825 on 2025-02-18
# Fetching full instrument data for regNo: 11820 on 2025-02-17
# Fetching full instrument data for regNo: 11820 on 2025-02-18
# Fetching full instrument data for regNo: 10639 on 2025-02-17
# Fetching full instrument data for regNo: 10639 on 2025-02-18
# Fetching full instrument data for regNo: 10845 on 2025-02-17
# Fetching full instrument data for regNo: 10845 on 2025-02-18
# Fetching full instrument data for regNo: 11384 on 2025-02-17
# Fetching full instrument data for regNo: 11384 on 2025-02-18
# Fetching full instrument data for regNo: 11142 on 2025-02-17
# Fetching full instrument data for regNo: 11142 on 2025-02-18
# Fetching full instrument data for regNo: 11145 on 2025-02-17
# Fetching full instrument data for regNo: 11145 on 2025-02-18
# Fetching full instrument data for regNo: 10837 on 2025-02-17
# Fetching full instrument data for regNo: 10837 on 2025-02-18
# Fetching full instrument data for regNo: 11553 on 2025-02-17
# Fetching full instrument data for regNo: 11553 on 2025-02-18
# Fetching full instrument data for regNo: 11385 on 2025-02-17
# Fetching full instrument data for regNo: 11385 on 2025-02-18
# Fetching full instrument data for regNo: 12207 on 2025-02-17
# Fetching full instrument data for regNo: 12207 on 2025-02-18
# Fetching full instrument data for regNo: 11951 on 2025-02-17
# Fetching full instrument data for regNo: 11951 on 2025-02-18
# Fetching full instrument data for regNo: 11290 on 2025-02-17
# Fetching full instrument data for regNo: 11290 on 2025-02-18
# Fetching full instrument data for regNo: 11460 on 2025-02-17
# Fetching full instrument data for regNo: 11460 on 2025-02-18
# Fetching full instrument data for regNo: 11551 on 2025-02-17
# Fetching full instrument data for regNo: 11551 on 2025-02-18
# Fetching full instrument data for regNo: 10896 on 2025-02-17
# Fetching full instrument data for regNo: 10896 on 2025-02-18
# Fetching full instrument data for regNo: 10789 on 2025-02-17
# Fetching full instrument data for regNo: 10789 on 2025-02-18
# Fetching full instrument data for regNo: 11394 on 2025-02-17
# Fetching full instrument data for regNo: 11394 on 2025-02-18
# Fetching full instrument data for regNo: 11310 on 2025-02-17
# Fetching full instrument data for regNo: 11310 on 2025-02-18
# Fetching full instrument data for regNo: 11621 on 2025-02-17
# Fetching full instrument data for regNo: 11621 on 2025-02-18
# Fetching full instrument data for regNo: 10843 on 2025-02-17
# Fetching full instrument data for regNo: 10843 on 2025-02-18
# Fetching full instrument data for regNo: 11499 on 2025-02-17
# Fetching full instrument data for regNo: 11499 on 2025-02-18
# Fetching full instrument data for regNo: 12150 on 2025-02-17
# Fetching full instrument data for regNo: 12150 on 2025-02-18
# Fetching full instrument data for regNo: 12170 on 2025-02-17
# Fetching full instrument data for regNo: 12170 on 2025-02-18
# Fetching full instrument data for regNo: 12086 on 2025-02-17
# Fetching full instrument data for regNo: 12086 on 2025-02-18
# Fetching full instrument data for regNo: 10929 on 2025-02-17
# Fetching full instrument data for regNo: 10929 on 2025-02-18
# Fetching full instrument data for regNo: 11775 on 2025-02-17
# Fetching full instrument data for regNo: 11775 on 2025-02-18
# Fetching full instrument data for regNo: 11903 on 2025-02-17
# Fetching full instrument data for regNo: 11903 on 2025-02-18
# Fetching full instrument data for regNo: 10919 on 2025-02-17
# Fetching full instrument data for regNo: 10919 on 2025-02-18
# Fetching full instrument data for regNo: 11256 on 2025-02-17
# Fetching full instrument data for regNo: 11256 on 2025-02-18
# Fetching full instrument data for regNo: 12107 on 2025-02-17
# Fetching full instrument data for regNo: 12107 on 2025-02-18
# Fetching full instrument data for regNo: 10897 on 2025-02-17
# Fetching full instrument data for regNo: 10897 on 2025-02-18
# Fetching full instrument data for regNo: 12023 on 2025-02-17
# Fetching full instrument data for regNo: 12023 on 2025-02-18
# Fetching full instrument data for regNo: 11886 on 2025-02-17
# Fetching full instrument data for regNo: 11886 on 2025-02-18
# Fetching full instrument data for regNo: 12227 on 2025-02-17
# Fetching full instrument data for regNo: 12227 on 2025-02-18
# Fetching full instrument data for regNo: 11233 on 2025-02-17
# Fetching full instrument data for regNo: 11233 on 2025-02-18
# Fetching full instrument data for regNo: 11764 on 2025-02-17
# Fetching full instrument data for regNo: 11764 on 2025-02-18
# Fetching full instrument data for regNo: 11295 on 2025-02-17
# Fetching full instrument data for regNo: 11295 on 2025-02-18
# Fetching full instrument data for regNo: 10782 on 2025-02-17
# Fetching full instrument data for regNo: 10782 on 2025-02-18
# Fetching full instrument data for regNo: 10706 on 2025-02-17
# Fetching full instrument data for regNo: 10706 on 2025-02-18
# Fetching full instrument data for regNo: 11665 on 2025-02-17
# Fetching full instrument data for regNo: 11665 on 2025-02-18
# Fetching full instrument data for regNo: 11924 on 2025-02-17
# Fetching full instrument data for regNo: 11924 on 2025-02-18
# Fetching full instrument data for regNo: 11985 on 2025-02-17
# Fetching full instrument data for regNo: 11985 on 2025-02-18
# Fetching full instrument data for regNo: 11197 on 2025-02-17
# Fetching full instrument data for regNo: 11197 on 2025-02-18
# Fetching full instrument data for regNo: 12225 on 2025-02-17
# Fetching full instrument data for regNo: 12225 on 2025-02-18
# Fetching full instrument data for regNo: 11099 on 2025-02-17
# Fetching full instrument data for regNo: 11099 on 2025-02-18
# Fetching full instrument data for regNo: 11512 on 2025-02-17
# Fetching full instrument data for regNo: 11512 on 2025-02-18
# Fetching full instrument data for regNo: 11334 on 2025-02-17
# Fetching full instrument data for regNo: 11334 on 2025-02-18
# Fetching full instrument data for regNo: 11772 on 2025-02-17
# Fetching full instrument data for regNo: 11772 on 2025-02-18
# Fetching full instrument data for regNo: 11927 on 2025-02-17
# Fetching full instrument data for regNo: 11927 on 2025-02-18
# Fetching full instrument data for regNo: 11173 on 2025-02-17
# Fetching full instrument data for regNo: 11173 on 2025-02-18
# Fetching full instrument data for regNo: 11340 on 2025-02-17
# Fetching full instrument data for regNo: 11340 on 2025-02-18
# Fetching full instrument data for regNo: 11615 on 2025-02-17
# Fetching full instrument data for regNo: 11615 on 2025-02-18
# Fetching full instrument data for regNo: 12010 on 2025-02-17
# Fetching full instrument data for regNo: 12010 on 2025-02-18
# Fetching full instrument data for regNo: 11885 on 2025-02-17
# Fetching full instrument data for regNo: 11885 on 2025-02-18
# Fetching full instrument data for regNo: 12138 on 2025-02-17
# Fetching full instrument data for regNo: 12138 on 2025-02-18
# Fetching full instrument data for regNo: 10855 on 2025-02-17
# Fetching full instrument data for regNo: 10855 on 2025-02-18
# Fetching full instrument data for regNo: 11141 on 2025-02-17
# Fetching full instrument data for regNo: 11141 on 2025-02-18
# Fetching full instrument data for regNo: 11704 on 2025-02-17
# Fetching full instrument data for regNo: 11704 on 2025-02-18
# Fetching full instrument data for regNo: 12115 on 2025-02-17
# Fetching full instrument data for regNo: 12115 on 2025-02-18
# Fetching full instrument data for regNo: 12183 on 2025-02-17
# Fetching full instrument data for regNo: 12183 on 2025-02-18
# Fetching full instrument data for regNo: 12005 on 2025-02-17
# Fetching full instrument data for regNo: 12005 on 2025-02-18
# Fetching full instrument data for regNo: 11675 on 2025-02-17
# Fetching full instrument data for regNo: 11675 on 2025-02-18
# Fetching full instrument data for regNo: 12179 on 2025-02-17
# Fetching full instrument data for regNo: 12179 on 2025-02-18
# Fetching full instrument data for regNo: 12166 on 2025-02-17
# Fetching full instrument data for regNo: 12166 on 2025-02-18
# Fetching full instrument data for regNo: 12061 on 2025-02-17
# Fetching full instrument data for regNo: 12061 on 2025-02-18
# Fetching full instrument data for regNo: 11260 on 2025-02-17
# Fetching full instrument data for regNo: 11260 on 2025-02-18
# Fetching full instrument data for regNo: 12116 on 2025-02-17
# Fetching full instrument data for regNo: 12116 on 2025-02-18
# Fetching full instrument data for regNo: 12126 on 2025-02-17
# Fetching full instrument data for regNo: 12126 on 2025-02-18
# Fetching full instrument data for regNo: 12018 on 2025-02-17
# Fetching full instrument data for regNo: 12018 on 2025-02-18
# Fetching full instrument data for regNo: 11435 on 2025-02-17
# Fetching full instrument data for regNo: 11435 on 2025-02-18
# Fetching full instrument data for regNo: 11411 on 2025-02-17
# Fetching full instrument data for regNo: 11411 on 2025-02-18
# Fetching full instrument data for regNo: 11223 on 2025-02-17
# Fetching full instrument data for regNo: 11223 on 2025-02-18
# Fetching full instrument data for regNo: 11922 on 2025-02-17
# Fetching full instrument data for regNo: 11922 on 2025-02-18
# Fetching full instrument data for regNo: 12205 on 2025-02-17
# Fetching full instrument data for regNo: 12205 on 2025-02-18
# Fetching full instrument data for regNo: 11198 on 2025-02-17
# Fetching full instrument data for regNo: 11198 on 2025-02-18
# Fetching full instrument data for regNo: 12022 on 2025-02-17
# Fetching full instrument data for regNo: 12022 on 2025-02-18
# Fetching full instrument data for regNo: 11463 on 2025-02-17
# Fetching full instrument data for regNo: 11463 on 2025-02-18
# Fetching full instrument data for regNo: 11941 on 2025-02-17
# Fetching full instrument data for regNo: 11941 on 2025-02-18
# Fetching full instrument data for regNo: 11447 on 2025-02-17
# Fetching full instrument data for regNo: 11447 on 2025-02-18
# Fetching full instrument data for regNo: 11929 on 2025-02-17
# Fetching full instrument data for regNo: 11929 on 2025-02-18
# Fetching full instrument data for regNo: 12184 on 2025-02-17
# Fetching full instrument data for regNo: 12184 on 2025-02-18
# Fetching full instrument data for regNo: 11131 on 2025-02-17
# Fetching full instrument data for regNo: 11131 on 2025-02-18
# Fetching full instrument data for regNo: 11655 on 2025-02-17
# Fetching full instrument data for regNo: 11655 on 2025-02-18
# Fetching full instrument data for regNo: 11813 on 2025-02-17
# Fetching full instrument data for regNo: 11813 on 2025-02-18
# Fetching full instrument data for regNo: 11674 on 2025-02-17
# Fetching full instrument data for regNo: 11674 on 2025-02-18
# Fetching full instrument data for regNo: 12020 on 2025-02-17
# Fetching full instrument data for regNo: 12020 on 2025-02-18
# Fetching full instrument data for regNo: 11595 on 2025-02-17
# Fetching full instrument data for regNo: 11595 on 2025-02-18
# Fetching full instrument data for regNo: 11878 on 2025-02-17
# Fetching full instrument data for regNo: 11878 on 2025-02-18
# Fetching full instrument data for regNo: 11339 on 2025-02-17
# Fetching full instrument data for regNo: 11339 on 2025-02-18
# Fetching full instrument data for regNo: 11773 on 2025-02-17
# Fetching full instrument data for regNo: 11773 on 2025-02-18
# Fetching full instrument data for regNo: 11091 on 2025-02-17
# Fetching full instrument data for regNo: 11091 on 2025-02-18
# Fetching full instrument data for regNo: 10589 on 2025-02-17
# Fetching full instrument data for regNo: 10589 on 2025-02-18
# Fetching full instrument data for regNo: 10719 on 2025-02-17
# Fetching full instrument data for regNo: 10719 on 2025-02-18
# Fetching full instrument data for regNo: 11822 on 2025-02-17
# Fetching full instrument data for regNo: 11822 on 2025-02-18
# Fetching full instrument data for regNo: 11603 on 2025-02-17
# Fetching full instrument data for regNo: 11603 on 2025-02-18
# Fetching full instrument data for regNo: 12148 on 2025-02-17
# Fetching full instrument data for regNo: 12148 on 2025-02-18
# Fetching full instrument data for regNo: 11534 on 2025-02-17
# Fetching full instrument data for regNo: 11534 on 2025-02-18
# Fetching full instrument data for regNo: 12168 on 2025-02-17
# Fetching full instrument data for regNo: 12168 on 2025-02-18
# Fetching full instrument data for regNo: 11882 on 2025-02-17
# Fetching full instrument data for regNo: 11882 on 2025-02-18
# Fetching full instrument data for regNo: 12157 on 2025-02-17
# Fetching full instrument data for regNo: 12157 on 2025-02-18
# Fetching full instrument data for regNo: 11410 on 2025-02-17
# Fetching full instrument data for regNo: 11410 on 2025-02-18
# Fetching full instrument data for regNo: 12111 on 2025-02-17
# Fetching full instrument data for regNo: 12111 on 2025-02-18
# Fetching full instrument data for regNo: 11618 on 2025-02-17
# Fetching full instrument data for regNo: 11618 on 2025-02-18
# Fetching full instrument data for regNo: 11899 on 2025-02-17
# Fetching full instrument data for regNo: 11899 on 2025-02-18
# Fetching full instrument data for regNo: 12046 on 2025-02-17
# Fetching full instrument data for regNo: 12046 on 2025-02-18
# Fetching full instrument data for regNo: 12177 on 2025-02-17
# Fetching full instrument data for regNo: 12177 on 2025-02-18
# Fetching full instrument data for regNo: 12198 on 2025-02-17
# Fetching full instrument data for regNo: 12198 on 2025-02-18
# Fetching full instrument data for regNo: 12206 on 2025-02-17
# Fetching full instrument data for regNo: 12206 on 2025-02-18
# Fetching full instrument data for regNo: 12215 on 2025-02-17
# Fetching full instrument data for regNo: 12215 on 2025-02-18
# Fetching full instrument data for regNo: 12216 on 2025-02-17
# Fetching full instrument data for regNo: 12216 on 2025-02-18
# Fetching full instrument data for regNo: 12220 on 2025-02-17
# Fetching full instrument data for regNo: 12220 on 2025-02-18
# Fetching full instrument data for regNo: 12231 on 2025-02-17
# Fetching full instrument data for regNo: 12231 on 2025-02-18
# Fetching full instrument data for regNo: 12232 on 2025-02-17
# Fetching full instrument data for regNo: 12232 on 2025-02-18
# Fetching full instrument data for regNo: 12234 on 2025-02-17
# Fetching full instrument data for regNo: 12234 on 2025-02-18
# Fetching full instrument data for regNo: 12237 on 2025-02-17
# Fetching full instrument data for regNo: 12237 on 2025-02-18
# Fetching full instrument data for regNo: 12238 on 2025-02-17
# Fetching full instrument data for regNo: 12238 on 2025-02-18
# Fetching full instrument data for regNo: 12245 on 2025-02-17
# Fetching full instrument data for regNo: 12245 on 2025-02-18
# Fetching full instrument data for regNo: 12246 on 2025-02-17
# Fetching full instrument data for regNo: 12246 on 2025-02-18
# Fetching full instrument data for regNo: 12248 on 2025-02-17
# Fetching full instrument data for regNo: 12248 on 2025-02-18
# Fetching full instrument data for regNo: 12250 on 2025-02-17
# Fetching full instrument data for regNo: 12250 on 2025-02-18
# Fetching full instrument data for regNo: 12251 on 2025-02-17
# Fetching full instrument data for regNo: 12251 on 2025-02-18
# Fetching full instrument data for regNo: 12252 on 2025-02-17
# Fetching full instrument data for regNo: 12252 on 2025-02-18
# Fetching full instrument data for regNo: 12268 on 2025-02-17
# Fetching full instrument data for regNo: 12268 on 2025-02-18
# Fetching full instrument data for regNo: 12270 on 2025-02-17
# Fetching full instrument data for regNo: 12270 on 2025-02-18
# Fetching full instrument data for regNo: 12273 on 2025-02-17
# Fetching full instrument data for regNo: 12273 on 2025-02-18
# Fetching full instrument data for regNo: 12274 on 2025-02-17
# Fetching full instrument data for regNo: 12274 on 2025-02-18
# Fetching full instrument data for regNo: 12279 on 2025-02-17
# Fetching full instrument data for regNo: 12279 on 2025-02-18
# Fetching full instrument data for regNo: 12281 on 2025-02-17
# Fetching full instrument data for regNo: 12281 on 2025-02-18
# Fetching full instrument data for regNo: 12284 on 2025-02-17
# Fetching full instrument data for regNo: 12284 on 2025-02-18
# Fetching full instrument data for regNo: 12286 on 2025-02-17
# Fetching full instrument data for regNo: 12286 on 2025-02-18
# Fetching full instrument data for regNo: 12287 on 2025-02-17
# Fetching full instrument data for regNo: 12287 on 2025-02-18
# Fetching full instrument data for regNo: 12288 on 2025-02-17
# Fetching full instrument data for regNo: 12288 on 2025-02-18
# Fetching full instrument data for regNo: 12290 on 2025-02-17
# Fetching full instrument data for regNo: 12290 on 2025-02-18
# Fetching full instrument data for regNo: 12292 on 2025-02-17
# Fetching full instrument data for regNo: 12292 on 2025-02-18
# Fetching full instrument data for regNo: 12293 on 2025-02-17
# Fetching full instrument data for regNo: 12293 on 2025-02-18
# Fetching full instrument data for regNo: 12295 on 2025-02-17
# Fetching full instrument data for regNo: 12295 on 2025-02-18
# Fetching full instrument data for regNo: 12297 on 2025-02-17
# Fetching full instrument data for regNo: 12297 on 2025-02-18
# Fetching full instrument data for regNo: 12301 on 2025-02-17
# Fetching full instrument data for regNo: 12301 on 2025-02-18
# Fetching full instrument data for regNo: 12304 on 2025-02-17
# Fetching full instrument data for regNo: 12304 on 2025-02-18
# Fetching full instrument data for regNo: 12309 on 2025-02-17
# Fetching full instrument data for regNo: 12309 on 2025-02-18
# Fetching full instrument data for regNo: 12310 on 2025-02-17
# Fetching full instrument data for regNo: 12310 on 2025-02-18
# Fetching full instrument data for regNo: 12314 on 2025-02-17
# Fetching full instrument data for regNo: 12314 on 2025-02-18
# Fetching full instrument data for regNo: 12322 on 2025-02-17
# Fetching full instrument data for regNo: 12322 on 2025-02-18
# Fetching full instrument data for regNo: 12323 on 2025-02-17
# Fetching full instrument data for regNo: 12323 on 2025-02-18
# Fetching full instrument data for regNo: 12324 on 2025-02-17
# Fetching full instrument data for regNo: 12324 on 2025-02-18
# Fetching full instrument data for regNo: 12327 on 2025-02-17
# Fetching full instrument data for regNo: 12327 on 2025-02-18
# Fetching full instrument data for regNo: 12329 on 2025-02-17
# Fetching full instrument data for regNo: 12329 on 2025-02-18
# Fetching full instrument data for regNo: 12332 on 2025-02-17
# Fetching full instrument data for regNo: 12332 on 2025-02-18
# Fetching full instrument data for regNo: 12334 on 2025-02-17
# Fetching full instrument data for regNo: 12334 on 2025-02-18
# Fetching full instrument data for regNo: 12337 on 2025-02-17
# Fetching full instrument data for regNo: 12337 on 2025-02-18
# Fetching full instrument data for regNo: 12339 on 2025-02-17
# Fetching full instrument data for regNo: 12339 on 2025-02-18
# Fetching full instrument data for regNo: 12342 on 2025-02-17
# Fetching full instrument data for regNo: 12342 on 2025-02-18
# Fetching full instrument data for regNo: 12344 on 2025-02-17
# Fetching full instrument data for regNo: 12344 on 2025-02-18
# Fetching full instrument data for regNo: 12345 on 2025-02-17
# Fetching full instrument data for regNo: 12345 on 2025-02-18
# Fetching full instrument data for regNo: 12356 on 2025-02-17
# Fetching full instrument data for regNo: 12356 on 2025-02-18
# Fetching full instrument data for regNo: 12357 on 2025-02-17
# Fetching full instrument data for regNo: 12357 on 2025-02-18
# Fetching full instrument data for regNo: 12358 on 2025-02-17
# Fetching full instrument data for regNo: 12358 on 2025-02-18
# Fetching full instrument data for regNo: 12359 on 2025-02-17
# Fetching full instrument data for regNo: 12359 on 2025-02-18
# Fetching full instrument data for regNo: 12362 on 2025-02-17
# Fetching full instrument data for regNo: 12362 on 2025-02-18
# Fetching full instrument data for regNo: 12365 on 2025-02-17
# Fetching full instrument data for regNo: 12365 on 2025-02-18
# Fetching full instrument data for regNo: 12377 on 2025-02-17
# Fetching full instrument data for regNo: 12377 on 2025-02-18
# Fetching full instrument data for regNo: 12378 on 2025-02-17
# Fetching full instrument data for regNo: 12378 on 2025-02-18
# Fetching full instrument data for regNo: 12392 on 2025-02-17
# Fetching full instrument data for regNo: 12392 on 2025-02-18
# Fetching full instrument data for regNo: 11688 on 2025-02-17
# Fetching full instrument data for regNo: 11688 on 2025-02-18
# Fetching full instrument data for regNo: 11777 on 2025-02-17
# Fetching full instrument data for regNo: 11777 on 2025-02-18
# Fetching full instrument data for regNo: 11324 on 2025-02-17
# Fetching full instrument data for regNo: 11324 on 2025-02-18
# Fetching full instrument data for regNo: 11769 on 2025-02-17
# Fetching full instrument data for regNo: 11769 on 2025-02-18
# Fetching full instrument data for regNo: 11803 on 2025-02-17
# Fetching full instrument data for regNo: 11803 on 2025-02-18
# Fetching full instrument data for regNo: 11986 on 2025-02-17
# Fetching full instrument data for regNo: 11986 on 2025-02-18
# Fetching full instrument data for regNo: 11538 on 2025-02-17
# Fetching full instrument data for regNo: 11538 on 2025-02-18
# Fetching full instrument data for regNo: 12073 on 2025-02-17
# Fetching full instrument data for regNo: 12073 on 2025-02-18
# Fetching full instrument data for regNo: 12047 on 2025-02-17
# Fetching full instrument data for regNo: 12047 on 2025-02-18
# Fetching full instrument data for regNo: 11681 on 2025-02-17
# Fetching full instrument data for regNo: 11681 on 2025-02-18
# Fetching full instrument data for regNo: 11511 on 2025-02-17
# Fetching full instrument data for regNo: 11511 on 2025-02-18
# Fetching full instrument data for regNo: 12149 on 2025-02-17
# Fetching full instrument data for regNo: 12149 on 2025-02-18
# Fetching full instrument data for regNo: 11807 on 2025-02-17
# Fetching full instrument data for regNo: 11807 on 2025-02-18
# Fetching full instrument data for regNo: 11925 on 2025-02-17
# Fetching full instrument data for regNo: 11925 on 2025-02-18
# Fetching full instrument data for regNo: 11934 on 2025-02-17
# Fetching full instrument data for regNo: 11934 on 2025-02-18
# Fetching full instrument data for regNo: 11346 on 2025-02-17
# Fetching full instrument data for regNo: 11346 on 2025-02-18
# Fetching full instrument data for regNo: 11994 on 2025-02-17
# Fetching full instrument data for regNo: 11994 on 2025-02-18
# Fetching full instrument data for regNo: 11752 on 2025-02-17
# Fetching full instrument data for regNo: 11752 on 2025-02-18
# Fetching full instrument data for regNo: 11446 on 2025-02-17
# Fetching full instrument data for regNo: 11446 on 2025-02-18
# Fetching full instrument data for regNo: 11987 on 2025-02-17
# Fetching full instrument data for regNo: 11987 on 2025-02-18
# Fetching full instrument data for regNo: 11359 on 2025-02-17
# Fetching full instrument data for regNo: 11359 on 2025-02-18
# Fetching full instrument data for regNo: 11306 on 2025-02-17
# Fetching full instrument data for regNo: 11306 on 2025-02-18
# Fetching full instrument data for regNo: 11836 on 2025-02-17
# Fetching full instrument data for regNo: 11836 on 2025-02-18
# Fetching full instrument data for regNo: 11798 on 2025-02-17
# Fetching full instrument data for regNo: 11798 on 2025-02-18
# Fetching full instrument data for regNo: 11982 on 2025-02-17
# Fetching full instrument data for regNo: 11982 on 2025-02-18
# Fetching full instrument data for regNo: 11895 on 2025-02-17
# Fetching full instrument data for regNo: 11895 on 2025-02-18
# Fetching full instrument data for regNo: 11891 on 2025-02-17
# Fetching full instrument data for regNo: 11891 on 2025-02-18
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:266: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_instruments = pd.concat(all_results, ignore_index=True)
# Instrument data saved to instrument_data.xlsx.
# Final data saved to updated_fund_data.xlsx.
# Applying mutualFundLicenses processing function...
# Data successfully processed and saved to updated_fund_data.xlsx with sheet name 'Fund_data'.
# Post-processing fund data...
# Reading post-processing data from updated_fund_data.xlsx...
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:141: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'[\u200c\u00A0ـ]', ' ', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:188: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'نو\s+ویرا', 'نوویرا', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:196: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'سبد\s+گردان', 'سبدگردان', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:199: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'سرمایه\s+گذاری', 'سرمایه‌گذاری', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:202: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'(مشاور)(سرمایه‌گذاری)', r'\1 \2', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:234: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'\s*\(سهامی خاص\)', '', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:235: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'\s*\(سهامی عام \)\s*', '', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:238: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: re.sub(r'\s*سهامی عام$', '', str(x)) if isinstance(x, str) else x)
# C:\Users\a.shokatabadi.TSD0\AppData\Local\Temp\ipykernel_17256\2697471586.py:241: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: '' if isinstance(x, str) and 'نامشخصنامشخص' in x else x)
# Post-processing completed. Updated data saved to updated_fund_data.xlsx.
# 📢 Fetching index data. This may take some time...
# ✅ Index data with returns saved to index_data.xlsx.
# 🔄 Merging updated_fund_data.xlsx and index_data.xlsx...
# ✅ Merged data saved to final_fund_index_data.xlsx
